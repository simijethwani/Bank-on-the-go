# %%
#Online Banking System

# %%
pip install notify-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install simple_colors
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#for colored font
import simple_colors as color
#for image purpose
from PIL import Image
#for times
import time
#for notification
from notifypy import Notify
#Notification for talktutor
notification = Notify()
notification.title = "BankOnTheGo"
notification.message = "BankOnTheGo is running..."
notification.icon = "app_icon.png"
notification.send()
#time.sleep(2)
#for GUI
from tkinter import*
from tkinter import ttk
from tkinter import messagebox
from tkinter.simpledialog import askstring
from tkinter import PhotoImage
import tkinter as tk
# Create An Objcet For Main Application Window (For Tk Class)
window = tk.Tk()
# Title of App
window.title("BankOnTheGo")
# Setting a geometry box
window.geometry("1000x560")
# App icon
window.iconbitmap("app_icon.ico")
# background image
window["bg"]='#BC7AF9'
# Show image using label
image9 = PhotoImage(file="coll1.png")
label9 = tk.Label(window, image=image9,bg="#BC7AF9",fg="#BC7AF9")
label9.place(x=800,y=230)
def command_profile():
    window = tk.Tk()
    # Title of App
    window.title("My Profile")
    # Setting a geometry box
    window.geometry("800x560")
    # App icon
    window.iconbitmap("app_icon.ico")
    
    
    window.mainloop()

image60 = tk.PhotoImage(file="but1.png")
button60 = tk.Button(window,image=image60,width=150,height=120,command=command_profile )
button60.place(x=10,y=460)
#button2recharge
image61 = tk.PhotoImage(file="but2.png")
button61 = tk.Button(window, image=image61,width=150,height=120)
button61.place(x=10,y=620)
#button3upi
image62 = tk.PhotoImage(file="but3.png")
button62 = tk.Button(window, image=image62,width=150,height=120)
button62.place(x=250,y=460)
#button4electricity
image63 = tk.PhotoImage(file="but4.png")
button63 = tk.Button(window, image=image63,width=150,height=120)
button63.place(x=250,y=620)
#button5water
image64 = tk.PhotoImage(file="but5.png")
button64 = tk.Button(window, image=image64,width=150,height=120)
button64.place(x=490,y=460)
#button6otheer
image65 = tk.PhotoImage(file="but6.png")
button65 = tk.Button(window, image=image65,width=150,height=120)
button65.place(x=490,y=620)

trial1= Label(window,bg="#BC7AF9",width=100,height=100)
trial1.place(x=10,y=460)
trial= Label(window,bg="#BC7AF9",width=100,height=100)
trial.place(x=800,y=230)
img1 = PhotoImage(file = "logo.png") 
img2 = PhotoImage(file = "appicon.png")
label1 = Label(window,image=img2)
label1.place(x=700,y=60)
label2 = Label(window,image=img1)
label2.place(x=330,y=250)

#list
l1= ["123456","789101","121212","232323"]
l2= ["1234","2345","5678","6789"]
font1 = ("Comic Sans MS",12)

   
# Define the global choices list
choices = ["Payee", "Lochan Jhalani", "Anand Emporium", "Ramesh Textile", "Muskan Jethwani"]
def command_enter():
    if cu1.get() in l1 and pi2.get() in l2:
        trial.destroy()
        start.destroy()
        cust.destroy()
        pin.destroy()
        cu1.destroy()
        pi2.destroy()
        label1.destroy()
        label2.destroy()
        trial1.destroy() 
        enter_btn.destroy()
        font1 = ("Courier New", 30,"bold underline")
        font2 = ("Courier New", 30,"bold italic")
        font3 = ("Comic Sans MS",12)
        label3 = tk.Label(window,image=img1, font=font1,fg="white").place(x=10,y=20)
        global label6
        label6 = tk.Label(window, text='''Total Amount:-
₹299942.97''',width=30, font=font2,bg="#A6FF96",fg="white")
        label6.place(x=10,y=140)
        global enter_btn1
        enter_btn1 = tk.Button(window,text="Show Statements",width=70,font=font3,bg="#FF3FA4",fg="white",command=command_show)
        enter_btn1.place(x=10,y=250)
        global buu2
        buu2 = tk.Button(window,text="Show Statements",width=70,font=font3,bg="#FF3FA4",fg="white",command=command_show)
        buu2.place(x=10,y=250)
        global bu3
        bu3 = tk.Button(window,text="New Transaction",width=70,font=font3,bg="#FF3FA4",fg="white",command=command_new)
        bu3.place(x=10,y=320)
        global buu4
        buu4 = tk.Button(window,text="Change ATM Pin",width=70,font=font3,bg="#FF3FA4",fg="white",command=change_pin)
        buu4.place(x=10,y=390)
        
    else:
        global fail
        fail = Label(window,width=33,text="Either Cust.ID or pin is incorrect!!",bg="white",fg="red")
        fail.place(x=900,y=600) 
        time.sleep(2)
        fail.destroy()

def command_show():
    # Create An Objcet For Main Application Window (For Tk Class)
    window = tk.Tk()
    # Title of App
    window.title("Past Transactions")
    # Setting a geometry box
    window.geometry("800x560")
    # App icon
    window.iconbitmap("app_icon.ico")
    # background image
    window["bg"]='#A6FF96'
    table_data = [
    ["Date","Type","Description","Paid Out","Paid In","Balance"],
    ["22 Oct 2019","Automated pay in","Various Payment","","190.43","1803.9"],
    ["22 Oct 2019","Digital banking","Amazon","","140.00","1613.5"],
    ["22 Oct 2019","Faster payment","Business Loan","14200.00","","1473.5"],
    ["22 Oct 2019","BACS","Amazon", "","50.90","1341.2"],
    ["22 Oct 2019","Faster payment","Amazon","","42.23","825.98"],
    ["23 Oct 2019","Faster payment","Business Loan","13000.00","","20745.98"],
    ["23 Oct 2019","BACS","Interest Paid","","4500","118284.43"],
    ["23 Oct 2019","BACS","Various Payment","","177.87","18034.43"],
    ["23 Oct 2019","BACS","Various Payment","","543.09","17857.21"],
    ["24 Oct 2019","Faster payment","DVLA","","430.00","177735.21"],
    ["1 Nov 2019","CHQ","Cheque 2203218","1,200.00","","16355.21"],
    ["1 Nov 2019","CHQ","Cheque 2209200","","2470.00","14072.54"],
    ["1 Nov 2019","Int.Bank","DVLA","","609.20","12309.00"],
    ["1 Nov 2019","Automated pay in","Petrol","","23.30","9035.90"],
    ["12 Dec 2019","Automated pay in","Bright forward","","780.00","6780.2"],
    ["12 Dec 2019","CHQ","Cheque 2209360","3450.00","","4009.12"],
    ["12 Dec 2019","BACS","MRC","","560.00","3548.14"]    
    ]

    # Create labels to display the table data
    for i, row in enumerate(table_data):
        for j, cell_value in enumerate(row):
            label = tk.Label(window, text=cell_value)
            label.grid(row=i, column=j, padx=6, pady=5)
            label.config(bg="#A6FF96",fg="white", font=("Helvetica",12,"bold"))
    window.mainloop()


def command_new():
    label6.destroy()
    enter_btn1.destroy()
    buu2.destroy()
    bu3.destroy()
    buu4.destroy()
    global trial2
    trial2= Label(window,bg="#BC7AF9",width=100,height=100)
    trial2.place(x=10,y=460)
    font1 = ("Georgia", 30,"bold italic")
    font2 = ("Courier New", 30,"bold italic")
    font3 = ("Comic Sans MS",12)
    font4 = ("Comic Sans MS",20)
    global label5
    label5 = tk.Label(window, text="Money Transfer to Existing Payee", font=font1,bg="#A6FF96",fg="white")
    label5.place(x=10,y=150)
    global bu4
    bu4 = tk.Button(window,text=" 👨🏻 Add New Payee ",font=font3,bg="#E90064",fg="white",command=command_newpayee)
    bu4.place(x=570,y=230)
    global payee
    payee= tk.Label(window,text="Choose Payee : ",bg="#FF3FA4",fg="white", font=font4)
    payee.place(x=50,y=300)
    
    # Create a StringVar to store the selected option
    selected_option = tk.StringVar()

    # Set an initial value for the selected option (optional)
    selected_option.set(choices[0])
    # Create a custom style for the OptionMenu
    style = ttk.Style()
    style.configure("Custom.TMenubutton", background="#FF3FA4",font=("Comic Sans MS",18))
    # Set the foreground (text) color for the options
    style.map("Custom.TMenubutton", foreground=[("active","white")])

    # Create the OptionMenu widget with the custom style
    global option_menu
    option_menu = ttk.OptionMenu(
        window, selected_option, choices[0], *choices, style="Custom.TMenubutton"
    )
    option_menu.place(x=300,y=300)
    global ammount
    ammount = Label(window,text="Ammount : ",bg="#FF3FA4",fg="white", font=font4)
    ammount.place(x=50,y=400)
    global a1
    a1 = Entry(window,width=25)
    a1.place(x=300,y=400)
    global remark
    remark = Label(window,text="Remark : ",bg="#FF3FA4",fg="white", font=font4)
    remark.place(x=50,y=500)
    global text
    text = tk.Text(window, height=5, width=25)
    text.place(x=300,y=500)
    global bu20
    bu20 = tk.Button(window,text=" Transfer Money ",font=font3,bg="#E90064",fg="white",command=command_tr)
    bu20.place(x=150,y=650)
    global back
    back = tk.Button(window,text="Back",bg="#FF3FA4",fg="white",font=(12),command=command_back,width=5)
    back.place(x=480,y=230)
    
def command_tr():
    global succ1
    succ1 = tk.Label(window,text="Money Transfered Successfully!!",bg="#BC7AF9",fg="red", font=("Tahoma",20))
    succ1.place(x=350,y=750)
    
    
    
def command_newpayee():
    font4 = ("Tahoma",30,"underline")
    font5 = ("Tahoma",20)
    font3 = ("Comic Sans MS",12)
    global label99
    label99 = tk.Label(window,bg="#BC7AF9",height=80,width=80)
    label99.place(x=50,y=300)
    global payeed
    payeed= tk.Label(window,text="Provide Payee Details :",bg="#BC7AF9",fg="white", font=font4)
    payeed.place(x=70,y=300)
    global bank
    bank= tk.Label(window,text="Enter The Bank Name: ",bg="#BC7AF9",fg="white", font=font5)
    bank.place(x=70,y=390)
    global b1
    b1 = Entry(window,width=35)
    b1.place(x=450,y=400)
    global acc
    acc= tk.Label(window,text="Enter Account Holder Name: ",bg="#BC7AF9",fg="white", font=font5)
    acc.place(x=70,y=450)
    global acc1
    acc1 = Entry(window, width=35)
    acc1.place(x=450,y=460)
    global num
    num= tk.Label(window,text="Enter Account Number: ",bg="#BC7AF9",fg="white", font=font5)
    num.place(x=70,y=510)
    global n1
    n1 = Entry(window,width=35,show="#")
    n1.place(x=450,y=520)
    global renum
    renum= tk.Label(window,text="Re-Enter Account Number: ",bg="#BC7AF9",fg="white", font=font5)
    renum.place(x=70,y=570)
    global rn1
    rn1 = Entry(window,width=35)
    rn1.place(x=450,y=580)  
    global ifs
    ifs= tk.Label(window,text="Enter IFSC code:  ",bg="#BC7AF9",fg="white", font=font5)
    ifs.place(x=70,y=630)
    global ifsc1
    ifsc1 = Entry(window,width=35)
    ifsc1.place(x=450,y=640)
    global bu30
    bu30 = tk.Button(window,text=" Add Payee ",font=font3,bg="#E90064",fg="white",command=command_added)
    bu30.place(x=400,y=700)
    global back1
    back1 = tk.Button(window,text="Back",bg="#FF3FA4",fg="white",font=(12),command=command_backkk,width=5)
    back1.place(x=480,y=230)

    
def command_added():
    
    font5 = ("Tahoma",10)
    if n1.get()!=rn1.get():
        global err
        err = tk.Label(window,text="*Account Number does not match..",bg="#BC7AF9",fg="red", font=font5)
        err.place(x=700,y=570)
    else:
        entry_value = acc1.get()
        if entry_value:# Check if the entry is not empty
            list1=[entry_value]
            if list1[0] in choices:
                global alr
                alr= tk.Label(window,text="Payee Already Exist..",bg="#BC7AF9",fg="red", font=("Tahoma",20))
                alr.place(x=350,y=750)
                err.destroy()
            else:
                global succ
                succ= tk.Label(window,text="Payee Added successfully!!",bg="#BC7AF9",fg="red", font=("Tahoma",20))
                succ.place(x=350,y=750)
                choices.extend(list1)
                err.destroy()
                
                
                
                        

    

def change_pin():
    old_pin = askstring("Enter Old PIN", "Enter your old PIN:")
    if old_pin == "2917":
        new_pin = askstring("Enter New PIN", "Enter your new PIN:")
        confirm_new_pin = askstring("Confirm New PIN", "Re-enter your new PIN:")
        if new_pin == confirm_new_pin:
            messagebox.showinfo("Success", "PIN changed successfully!")
        else:
            messagebox.showerror("Error", "New PINs do not match. Please try again.")
    else:
        messagebox.showerror("Error", "Invalid old PIN. Please try again.")

def command_back():
    label5.destroy()
    bu4.destroy()
    payee.destroy()
    option_menu.destroy()
    ammount.destroy()
    a1.destroy()
    remark.destroy()
    text.destroy()
    bu20.destroy()
    back.destroy()
    trial2.destroy()
    
    font1 = ("Courier New", 30,"bold underline")
    font2 = ("Courier New", 30,"bold italic")
    font3 = ("Comic Sans MS",12)
    label3 = tk.Label(window,image=img1, font=font1,fg="white").place(x=10,y=20)
    global label6
    label6 = tk.Label(window, text='''Total Amount:-
₹299942.97''',width=30, font=font2,bg="#A6FF96",fg="white")
    label6.place(x=10,y=140)
    global enter_btn1
    enter_btn1 = tk.Button(window,text="Show Statements",width=70,font=font3,bg="#FF3FA4",fg="white",command=command_show)
    enter_btn1.place(x=10,y=250)
    global buu2
    buu2 = tk.Button(window,text="Show Statements",width=70,font=font3,bg="#FF3FA4",fg="white",command=command_show)
    buu2.place(x=10,y=250)
    global bu3
    bu3 = tk.Button(window,text="New Transaction",width=70,font=font3,bg="#FF3FA4",fg="white",command=command_new)
    bu3.place(x=10,y=320)
    global buu4
    buu4 = tk.Button(window,text="Change ATM Pin",width=70,font=font3,bg="#FF3FA4",fg="white",command=change_pin)
    buu4.place(x=10,y=390)
def command_backkk():
    label5.destroy()
    bu4.destroy()
    payee.destroy()
    option_menu.destroy()
    ammount.destroy()
    a1.destroy()
    remark.destroy()
    text.destroy()
    bu20.destroy()
    back.destroy()
    trial2.destroy()
    label99.destroy()
    payeed.destroy()
    bank.destroy()
    b1.destroy()
    acc.destroy()
    acc1.destroy()
    num.destroy()
    n1.destroy()
    renum.destroy()
    rn1.destroy()
    ifs.destroy()
    ifsc1.destroy()
    bu30.destroy()
    back1.destroy()
    font1 = ("Courier New", 30,"bold underline")
    font2 = ("Courier New", 30,"bold italic")
    font3 = ("Comic Sans MS",12)
    label3 = tk.Label(window,image=img1, font=font1,fg="white").place(x=10,y=20)
    global label6
    label6 = tk.Label(window, text='''Total Amount:-
₹299942.97''',width=30, font=font2,bg="#A6FF96",fg="white")
    label6.place(x=10,y=140)
    global enter_btn1
    enter_btn1 = tk.Button(window,text="Show Statements",width=70,font=font3,bg="#FF3FA4",fg="white",command=command_show)
    enter_btn1.place(x=10,y=250)
    global buu2
    buu2 = tk.Button(window,text="Show Statements",width=70,font=font3,bg="#FF3FA4",fg="white",command=command_show)
    buu2.place(x=10,y=250)
    global bu3
    bu3 = tk.Button(window,text="New Transaction",width=70,font=font3,bg="#FF3FA4",fg="white",command=command_new)
    bu3.place(x=10,y=320)
    global buu4
    buu4 = tk.Button(window,text="Change ATM Pin",width=70,font=font3,bg="#FF3FA4",fg="white",command=change_pin)
    buu4.place(x=10,y=390)
    succ.destroy()
    alr.destroy()

def command_showw():
    # Create An Objcet For Main Application Window (For Tk Class)
    window = tk.Tk()
    # Title of App
    window.title("Past Transactions")
    # Setting a geometry box
    window.geometry("800x560")
    # App icon
    window.iconbitmap("app_icon.ico")
    # background image
    window["bg"]='#A6FF96'
    table_data = [
    ["Date","Type","Description","Paid Out","Paid In","Balance"],
    ["22 Oct 2019","Automated pay in","Various Payment","","190.43","1803.9"],
    ["22 Oct 2019","Digital banking","Amazon","","140.00","1613.5"],
    ["22 Oct 2019","Faster payment","Business Loan","14200.00","","1473.5"],
    ["22 Oct 2019","BACS","Amazon", "","50.90","1341.2"],
    ["22 Oct 2019","Faster payment","Amazon","","42.23","825.98"],
    ["23 Oct 2019","Faster payment","Business Loan","13000.00","","20745.98"],
    ["23 Oct 2019","BACS","Interest Paid","","4500","118284.43"],
    ["23 Oct 2019","BACS","Various Payment","","177.87","18034.43"],
    ["23 Oct 2019","BACS","Various Payment","","543.09","17857.21"],
    ["24 Oct 2019","Faster payment","DVLA","","430.00","177735.21"],
    ["1 Nov 2019","CHQ","Cheque 2203218","1,200.00","","16355.21"],
    ["1 Nov 2019","CHQ","Cheque 2209200","","2470.00","14072.54"],
    ["1 Nov 2019","Int.Bank","DVLA","","609.20","12309.00"],
    ["1 Nov 2019","Automated pay in","Petrol","","23.30","9035.90"],
    ["12 Dec 2019","Automated pay in","Bright forward","","780.00","6780.2"],
    ["12 Dec 2019","CHQ","Cheque 2209360","3450.00","","4009.12"],
    ["12 Dec 2019","BACS","MRC","","560.00","3548.14"]    
    ]

    # Create labels to display the table data
    for i, row in enumerate(table_data):
        for j, cell_value in enumerate(row):
            label = tk.Label(window, text=cell_value)
            label.grid(row=i, column=j, padx=6, pady=5)
            label.config(bg="#A6FF96",fg="white", font=("Helvetica",12,"bold"))
    window.mainloop()
    
    
start = tk.Label(window,width=40,height=2,text="Enter Login Details :",bg="#FF3FA4",fg="white", font=font1)
start.place(x=600,y=400)
cust= tk.Label(window,width=10,text="Cust.ID",bg="#FF3FA4",fg="white", font=font1)
cust.place(x=600,y=500)
cu1 = tk.Entry(window,width=25)
cu1.place(x=720,y=500)
pin = tk.Label(window,width=10,text="Pin",bg="#FF3FA4",fg="white", font=font1)
pin.place(x=600,y=550)
pi2 = tk.Entry(window,width=25,show="*")
pi2.place(x=720,y=550)
enter_btn = tk.Button(window,width=8,text="EnterIn!!", font=font1,activebackground="#FF3FA4",activeforeground="white",command=command_enter)
enter_btn.place(x=700,y=600)

   
    
    
window.mainloop()

# %%
import tkinter as tk
from tkinter import *

# %%
import tkinter as tk
from tkinter import *
# Create a Tkinter window
window = tk.Tk()
window.title("Font Family Example")
label = Label(window,width=700,height=112,bg="#BC7AF9").place(x=10,y=20)

# List of font families to use
font_families = ["Arial", "Helvetica", "Times", "Courier", "Verdana", "Georgia", "Tahoma", "Comic Sans MS"]

# Create labels with different font families
for family in font_families:
    label = tk.Label(window, text=f"Font: {family}", font=(family, 16))
    label.pack()

# Start the Tkinter main loop
window.mainloop()
